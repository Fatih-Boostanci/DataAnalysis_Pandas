# %% [markdown]
# # Advanced Pandas

# %% [markdown]
# # Linkedin Learning (28 Apr 22)

# %% [markdown]
# ## From Beginner to Advanced pandas

# %% [markdown]
# ![3D8C0D7B-1199-4461-B056-3E30DA57623F_4_5005_c.jpeg](attachment:3D8C0D7B-1199-4461-B056-3E30DA57623F_4_5005_c.jpeg)

# %% [markdown]
# ![AC7B1AD9-7CD9-4184-9953-82FF26A14339_4_5005_c.jpeg](attachment:AC7B1AD9-7CD9-4184-9953-82FF26A14339_4_5005_c.jpeg)

# %% [markdown]
# ![C747B4BB-59A1-4A58-B39A-1C1202FB4AD3.jpeg](attachment:C747B4BB-59A1-4A58-B39A-1C1202FB4AD3.jpeg)

# %%
import numpy as np
import pandas as pd

# %%
scores = {"name": ["Ray", "Japhy", "Zosa"],
         "city": ["San Francisco", "San Francisco", "Denver"],
         "score": [75, 92, 94]
         }

# %%
df = pd.DataFrame(scores)

# %%
df
# Out:
#     name           city  score
# 0    Ray  San Francisco     75
# 1  Japhy  San Francisco     92
# 2   Zosa         Denver     94

# %%
df["score"]
# Out:
# 0    75
# 1    92
# 2    94
# Name: score, dtype: int64

# %%
df["name city"] = df["name"] + "_" + df["city"]

# %%
df
# Out:
#     name           city  score            name city
# 0    Ray  San Francisco     75    Ray_San Francisco
# 1  Japhy  San Francisco     92  Japhy_San Francisco
# 2   Zosa         Denver     94          Zosa_Denver

# %%
df[df["score"]>90]
# Out:
#     name           city  score            name city
# 1  Japhy  San Francisco     92  Japhy_San Francisco
# 2   Zosa         Denver     94          Zosa_Denver

# %% [markdown]
# ### Top Pandas Functions

# %% [markdown]
# ![2B7F1CBC-B6C3-43CC-B428-A4B573DBCFB3.jpeg](attachment:2B7F1CBC-B6C3-43CC-B428-A4B573DBCFB3.jpeg)

# %%
import numpy as np
import pandas as dp

# %%
pwd iris.csv
# Out:
# '/Users/fatih/IT/DATA_ANALYSIS/Pandas'

# %% [markdown]
# __import CSV with pd.read_csv()__

# %%
iris = pd.read_csv("/Users/fatih/IT/DATA_ANALYSIS/Pandas/iris.csv/iris.csv")

# %%
# show the shape of the file
iris.shape   # we can not reshape a csv.file
# Out:
# (150, 5)

# %%
iris.head(5)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %% [markdown]
# __Datatypes__<br>
#
# __will influences what kind of ops you use__

# %%
iris.dtypes  # 2 kind of data types
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %% [markdown]
# __Subsetting your data with loc & iloc__<br>

# %%
# Access a group of rows and columns by label(s) or a boolean array.
# start and stop are included
iris.loc[3:5]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
iris.loc[3, "sepal.length"]
# Out:
# 4.6

# %%
# Purely integer-location based indexing for selection by position.
iris.iloc[3, 0]
# Out:
# 4.6

# %% [markdown]
# __Export your data as csv using to_csv__<br>
#
# __data transformation w/ Pandas__

# %%
# Write object to a comma-separated values (csv) file.

iris.to_csv("iris-output.csv", index=False) #index is not included

# %% [markdown]
# __See Also__<br>
# --------<br>
# __read_csv__ : Load a CSV file into a DataFrame.<br>
# __to_excel__ : Write DataFrame to an Excel file.

# %% [markdown]
# ### Pandas Options

# %%
import numpy as np
import pandas as dp

# %%
emissions = pd.DataFrame({"country": ["China", "United States", "India"],
                         "year": ["2018", "2018", "2018"],
                         "co2_emissions": [10060000000.0, 5410000000.0, 2650000000.0]})

# %%
emissions
# Out:
#          country  year  co2_emissions
# 0          China  2018   1.006000e+10
# 1  United States  2018   5.410000e+09
# 2          India  2018   2.650000e+09

# %%
# set_option(pat, value)
# Sets the value of the specified option
# no return


# pd.set_option("max_rows", 2)

# %%
emissions
# Out:
#    country  year  co2_emissions
# 0    China  2018   1.006000e+10
# ..     ...   ...            ...
# 2    India  2018   2.650000e+09
#
# [3 rows x 3 columns]

# %%
# pd.set_option("max_columns", 2)

# %%
emissions
# Out:
#    country  ... co2_emissions
# 0    China  ...  1.006000e+10
# ..     ...  ...           ...
# 2    India  ...  2.650000e+09
#
# [3 rows x 3 columns]

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
emissions
# Out:
#    country  ...     co2_emissions
# 0    China  ... 10,060,000,000.00
# ..     ...  ...               ...
# 2    India  ...  2,650,000,000.00
#
# [3 rows x 3 columns]

# %% [markdown]
# ## Advanced Calculations

# %% [markdown]
# ### Data type conversions using pandas

# %%
import pandas as pd

# %%
pwd planets.csv
# Out:
# '/Users/fatih/IT/DATA_ANALYSIS/Pandas'

# %%
planets = pd.read_csv("/Users/fatih/IT/DATA_ANALYSIS/Pandas/planets/planets.csv")

# %%
planets.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
planets
# Out:
#       Name   Diameter          Mass   Inclination   Eccentricity  \
# 0  Mercury   4,879.40   3.302×10^23          7.00           0.21
# 1    Venus  12,103.60   4.869×10^24          3.39           0.01
# 2    Earth  12,756.30   5.974×10^24          0.00           0.02
# 3     Mars   6,794.40   6.419×10^23          1.85           0.09
# 4  Jupiter 142,984.00   1.899×10^27          1.31           0.05
# 5   Saturn 120,536.00   5.688×10^26          2.48           0.05
# 6   Uranus  51,118.00   8.683×10^25          0.77           0.05
# 7  Neptune  49,572.00   1.024×10^26          1.77           0.01
# 8    Pluto   2,370.00     1.3×10^22         17.09           0.25
#
#     Semi_majorAxis   SurfaceGravity   OrbitalPeriod   SiderealRotation  \
# 0             0.39             3.70            0.24              58.65
# 1             0.72             8.87            0.61             243.02
# 2             1.00             9.78            1.00               1.00
# ...

# %%
planets.head(3)
# Out:
#             method  number  orbital_period  mass  distance  year
# 0  Radial Velocity       1          269.30  7.10     77.40  2006
# 1  Radial Velocity       1          874.77  2.21     56.95  2008
# 2  Radial Velocity       1          763.00  2.60     19.84  2011

# %%
planets.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
planets.mean()
# Out:
# /var/folders/cv/t5lmh27d0bd2hlz5c0h0ts2m0000gn/T/ipykernel_1748/656747818.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   planets.mean()
# number               1.79
# orbital_period   2,002.92
# mass                 2.64
# distance           264.07
# year             2,009.07
# dtype: float64

# %%
planets["OrbitalPeriod"][0] / planets["Eccentricity"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OrbitalPeriod'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
planets["Inclination"][0].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Inclination'
#
# The above exception was the direct cause of the following exception:
#
# ...
